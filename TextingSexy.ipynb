# %% [markdown]
# <a href="https://colab.research.google.com/github/Grumpyaloha/Sexy-Training-Data/blob/main/TextingSexy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install dependencies as needed:
# pip install kagglehub[hf-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = ""

# Load the latest version
hf_dataset = kagglehub.load_dataset(
  KaggleDatasetAdapter.HUGGING_FACE,
  "harsh03/sexually-explicit-comments",
  file_path,
  # Provide any additional arguments like
  # sql_query, hf_kwargs, or pandas_kwargs. See
  # the documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterhugging_face
)

print("Hugging Face Dataset:", hf_dataset)
# Out:
# <ipython-input-1-db98d1d78cbd>:10: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   hf_dataset = kagglehub.load_dataset(
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-db98d1d78cbd> in <cell line: 0>()
#       8
#       9 # Load the latest version
# ---> 10 hf_dataset = kagglehub.load_dataset(
#      11   KaggleDatasetAdapter.HUGGING_FACE,
#      12   "harsh03/sexually-explicit-comments",
#
# /usr/local/lib/python3.11/dist-packages/kagglehub/datasets.py in load_dataset(adapter, handle, path, pandas_kwargs, sql_query, hf_kwargs)
#     140 ) -> Any:  # noqa: ANN401
#     141     warnings.warn("load_dataset is deprecated and will be removed in future version.", DeprecationWarning, stacklevel=2)
# --> 142     return dataset_load(adapter, handle, path, pandas_kwargs=pandas_kwargs, sql_query=sql_query, hf_kwargs=hf_kwargs)
# ...

# %%
# Install dependencies as needed:
# !pip install kagglehub[hf-datasets] # Uncomment and execute this line to install necessary dependencies
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = ""

# Load the latest version
hf_dataset = kagglehub.load_dataset(
  KaggleDatasetAdapter.HUGGING_FACE,
  "harsh03/sexually-explicit-comments",
  file_path,
  # Provide any additional arguments like
  # sql_query, hf_kwargs, or pandas_kwargs. See
  # the documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterhugging_face
)

print("Hugging Face Dataset:", hf_dataset)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.4/485.4 kB 9.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 13.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 16.6 MB/s eta 0:00:00
# ...
# <ipython-input-2-1a900e2dab09>:10: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   hf_dataset = kagglehub.load_dataset(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-1a900e2dab09> in <cell line: 0>()
#       8
#       9 # Load the latest version
# ---> 10 hf_dataset = kagglehub.load_dataset(
#      11   KaggleDatasetAdapter.HUGGING_FACE,
#      12   "harsh03/sexually-explicit-comments",
#
# ...

# %%
# !pip install kagglehub[hf-datasets] # Uncomment and execute this line to install necessary dependencies
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "train.csv" # Changed to the actual filename in the dataset

# Load the latest version
hf_dataset = kagglehub.load_dataset(
  KaggleDatasetAdapter.HUGGING_FACE,
  "harsh03/sexually-explicit-comments",
  file_path,
  # Provide any additional arguments like
  # sql_query, hf_kwargs, or pandas_kwargs. See
  # the documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterhugging_face
)

print("Hugging Face Dataset:", hf_dataset)
# Out:
# ...
# <ipython-input-3-b5aff490a3e3>:9: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   hf_dataset = kagglehub.load_dataset(
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/kagglehub/exceptions.py in kaggle_api_raise_for_status(response, resource_handle)
#      65     try:
# ---> 66         response.raise_for_status()
#      67     except requests.HTTPError as e:
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#
# HTTPError: 404 Client Error: Not Found for url: https://www.kaggle.com/api/v1/datasets/download/harsh03/sexually-explicit-comments?dataset_version_number=1&file_name=train.csv
#
# ...

# %%
# !huggingface-cli datasets info your_dataset_id
# Out:
# usage: huggingface-cli <command> [<args>]
# huggingface-cli: error: argument {download,upload,repo-files,env,login,whoami,logout,auth,repo,lfs-enable-largefiles,lfs-multipart-upload,scan-cache,delete-cache,tag,version,upload-large-folder}: invalid choice: 'datasets' (choose from 'download', 'upload', 'repo-files', 'env', 'login', 'whoami', 'logout', 'auth', 'repo', 'lfs-enable-largefiles', 'lfs-multipart-upload', 'scan-cache', 'delete-cache', 'tag', 'version', 'upload-large-folder')

# %%
# !pip install datasets
from datasets import load_dataset

# Load the dataset directly using Hugging Face's datasets library
dataset = load_dataset("harsh03/sexually-explicit-comments", data_files="train.csv")

# Print the dataset
print(dataset)
# Out:
# ...
# ---------------------------------------------------------------------------
# DatasetNotFoundError                      Traceback (most recent call last)
# <ipython-input-5-6468aa548c15> in <cell line: 0>()
#       3
#       4 # Load the dataset directly using Hugging Face's datasets library
# ----> 5 dataset = load_dataset("harsh03/sexually-explicit-comments", data_files="train.csv")
#       6
#       7 # Print the dataset
#
# /usr/local/lib/python3.11/dist-packages/datasets/load.py in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2127
#    2128     # Create a dataset builder
# -> 2129     builder_instance = load_dataset_builder(
#    2130         path=path,
#    2131         name=name,
#
# ...

# %%
# !pip install datasets
from datasets import load_dataset

# Try loading the dataset without specifying data_files
dataset = load_dataset("harsh03/sexually-explicit-comments")

# Print the dataset
print(dataset)
# Out:
# ...
# ---------------------------------------------------------------------------
# DatasetNotFoundError                      Traceback (most recent call last)
# <ipython-input-6-c37f8a727abf> in <cell line: 0>()
#       3
#       4 # Try loading the dataset without specifying data_files
# ----> 5 dataset = load_dataset("harsh03/sexually-explicit-comments")
#       6
#       7 # Print the dataset
#
# /usr/local/lib/python3.11/dist-packages/datasets/load.py in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2127
#    2128     # Create a dataset builder
# -> 2129     builder_instance = load_dataset_builder(
#    2130         path=path,
#    2131         name=name,
#
# ...

# %%
import pandas as pd

df = pd.read_csv("hf://datasets/Maxx0/Texting_sex/train.csv")

# %%
df
# Out:
#                                              thread_title  \
# 0                More Grim Tales (Renesmee Cullen and I )
# 1                More Grim Tales (Renesmee Cullen and I )
# 2                More Grim Tales (Renesmee Cullen and I )
# 3                            Scissors 61 [Blistered & Me]
# 4                           The Bond Between Two Elements
# ...                                                   ...
# 260076  You are My Universe (MysteriousD/DaddysLittleS...
# 260077  You are My Universe (MysteriousD/DaddysLittleS...
# 260078  You are My Universe (MysteriousD/DaddysLittleS...
# 260079  You are My Universe (MysteriousD/DaddysLittleS...
# 260080  You are My Universe (MysteriousD/DaddysLittleS...
#
#                                                   message  \
# 0       Grim nodded and began pushing harder and faste...
# 1       She gasped softly and let out a pleasurable mo...
# 2       Grim held onto Mini and smiled and kissed alon...
# ...
